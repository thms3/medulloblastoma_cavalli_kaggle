# %% [markdown]
# # Pearson correlation

# %%
# import lib
import numpy as np
import pandas as pd

# %%
rng = np.random.default_rng(4582345683546)

m = 120
n = 330
nx = 160
ny = n - nx

data = rng.random((m, n))
column_names = ([f'_PC{i}' for i in range(nx)] 
                + [f'_lncRNAs{i}' for i in range(ny)])
lncRNA_PC_T = pd.DataFrame(data, columns=column_names)

# %%
lncRNA_PC_T
# Out:
#          _PC0      _PC1      _PC2      _PC3      _PC4      _PC5      _PC6  \
# 0    0.280900  0.001448  0.027928  0.337749  0.682488  0.600051  0.526520
# 1    0.675633  0.598406  0.835905  0.852677  0.882882  0.288680  0.893689
# 2    0.791960  0.151214  0.426073  0.491463  0.993709  0.965380  0.525757
# 3    0.345313  0.059499  0.420587  0.271361  0.882440  0.648232  0.507514
# 4    0.275378  0.254446  0.848173  0.520497  0.951239  0.503223  0.961480
# ..        ...       ...       ...       ...       ...       ...       ...
# 115  0.122689  0.384899  0.770796  0.341601  0.621454  0.070699  0.556214
# 116  0.586044  0.995512  0.375057  0.526370  0.946351  0.422344  0.469472
# 117  0.954292  0.935925  0.880770  0.766003  0.626403  0.574287  0.315012
# 118  0.570509  0.878175  0.310905  0.457772  0.486288  0.160115  0.436907
# 119  0.718838  0.346552  0.404026  0.699118  0.996364  0.727272  0.121324
#
#          _PC7      _PC8      _PC9  ...  _lncRNAs160  _lncRNAs161  _lncRNAs162  \
# 0    0.084916  0.833719  0.371976  ...     0.983245     0.956690     0.112283
# 1    0.545906  0.819584  0.460990  ...     0.024071     0.341727     0.523100
# 2    0.089036  0.002369  0.589183  ...     0.487754     0.306396     0.475312
# 3    0.126179  0.628951  0.700430  ...     0.193933     0.934100     0.558114
# 4    0.187399  0.946201  0.586077  ...     0.190908     0.112905     0.459866
# ..        ...       ...       ...  ...          ...          ...          ...
# 115  0.427497  0.579688  0.591669  ...     0.163702     0.868754     0.869039
# 116  0.187648  0.830351  0.311740  ...     0.715733     0.759228     0.455834
# 117  0.216482  0.641772  0.861348  ...     0.005379     0.589101     0.973884
# 118  0.598360  0.376603  0.722815  ...     0.768415     0.456061     0.399188
# 119  0.296300  0.417149  0.299770  ...     0.458990     0.747214     0.087043
#
#      _lncRNAs163  _lncRNAs164  _lncRNAs165  _lncRNAs166  _lncRNAs167  \
# 0       0.416037     0.847787     0.200446     0.985431     0.861864
# 1       0.572442     0.031956     0.245020     0.289259     0.730080
# 2       0.978334     0.022493     0.511281     0.095478     0.622551
# 3       0.083293     0.080865     0.934729     0.277268     0.897894
# 4       0.106023     0.415205     0.779767     0.899239     0.822693
# ..           ...          ...          ...          ...          ...
# 115     0.560948     0.407106     0.084038     0.334843     0.850289
# 116     0.390192     0.573611     0.503640     0.098833     0.824145
# 117     0.290060     0.895838     0.111087     0.418049     0.804445
# 118     0.278927     0.921090     0.679190     0.244323     0.861309
# 119     0.061404     0.649968     0.293769     0.366426     0.114610
#
#      _lncRNAs168  _lncRNAs169
# 0       0.359156     0.127048
# 1       0.642509     0.440972
# 2       0.770534     0.027047
# 3       0.903043     0.468979
# 4       0.827596     0.424855
# ..           ...          ...
# 115     0.539801     0.811079
# 116     0.333262     0.678541
# 117     0.440579     0.370669
# 118     0.855939     0.419645
# 119     0.010621     0.772093
#
# [120 rows x 330 columns]
